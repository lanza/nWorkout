# %%
import test

# %%
data = test.get_data()

# %%
# Out:
# [Workout(isComplete=True, finishDate=datetime.datetime(1985, 6, 15, 22, 29, 43, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000), 'EDT')), isWorkout=True, lifts=[Lift(name='Squat', sets=[Set(completedReps=5, completedWeight=45, reps=5, weight=45, note='', isWarmup=False, isWorkout=True), Set(completedReps=5, completedWeight=45, reps=5, weight=45, note='', isWarmup=False, isWorkout=True)]), Lift(name='Deadlift', sets=[Set(completedReps=5, completedWeight=135, reps=5, weight=135, note='', isWarmup=False, isWorkout=True), Set(completedReps=5, completedWeight=135, reps=5, weight=135, note='', isWarmup=False, isWorkout=True), Set(completedReps=4, completedWeight=155, reps=4, weight=155, note='', isWarmup=False, isWorkout=True)]), Lift(name='Press', sets=[Set(completedReps=5, completedWeight=45, reps=5, weight=45, note='', isWarmup=False, isWorkout=True), Set(completedReps=5, completedWeight=65, reps=5, weight=65, note='', isWarmup=False, isWorkout=True), Set(completedRe
# ...
